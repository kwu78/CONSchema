# %%
import pandas as pd
real_estate_ny=pd.read_excel('./dataset/real_estate_nky.xlsx')

# %%
real_estate_ny.columns=real_estate_ny.columns.str.replace('/house_listing/', '')

# %%
real_estate_ny
# Out:
#          agent_phone               agent basement bath_1/dimension  \
# 0     (606) 525-7000          FRED BURCH     Full             FULL
# 1     (606) 341-9000        STEVE TUCKER     Part             FULL
# 2     (606) 371-4777          JOAN DIXON     Full             FULL
# 3     (606) 372-6000  PATRICIA VALENTINE    Crawl             FULL
# 4     (606) 341-7400         DAVE WHALEN     Part              NaN
# ...              ...                 ...      ...              ...
# 1905  (606) 824-9800          JUDY WELLS     None             FULL
# 1906  (606) 635-7388     STEPHEN B JELEN     None             FULL
# 1907  (606) 586-4419         MIKE REEVES     Full             FULL
# 1908  (513) 469-2424         AL HENCHECK     None             FULL
# 1909  (606) 781-5000       CATHY HORNSBY     None             FULL
#
#      bath_1/level bath_2/dimension bath_2/level bath_3/dimension bath_3/level  \
# 0               1             FULL            1              NaN          NaN
# ...

# %%
real_estate_texas=pd.read_excel('./dataset/real_estate_texas.xlsx')

# %%
real_estate_texas.columns=real_estate_texas.columns.str.replace('/house_listing/', '')

# %%
real_estate_texas
# Out:
#        #id agent_information/email agent_information/fax  \
# 0        1                     NaN                   NaN
# 1        2         JLee225@aol.com         (361)853-9095
# 2        2         JLee225@aol.com         (361)853-9095
# 3        2         JLee225@aol.com         (361)853-9095
# 4        3     C21Linda@excite.com         (361)592-9300
# ...    ...                     ...                   ...
# 8281  2157       irona@maxxrep.com         (254)634-3291
# 8282  2157       irona@maxxrep.com         (254)634-3291
# 8283  2157       irona@maxxrep.com         (254)634-3291
# 8284  2157       irona@maxxrep.com         (254)634-3291
# 8285  2157       irona@maxxrep.com         (254)634-3291
#
#      agent_information/mobile agent_information/name agent_information/office  \
# 0                         NaN          Larry Pruneda                      NaN
# 1                         NaN              Jerry Lee            (361)853-2121
# ...

# %%
real_estate_winder=pd.read_excel('./dataset/real_estate_windermere.xlsx')

# %%
real_estate_winder.columns=real_estate_winder.columns.str.replace('/house_listing/', '')

# %%
real_estate_winder
# Out:
#        #id          ac                address  \
# 0        1  Not Listed                    NaN
# 1        2         yes                    NaN
# 2        3         yes                    NaN
# 3        4         yes                    NaN
# 4        5         yes                    NaN
# ...    ...         ...                    ...
# 5303  3001         NaN  1463 Johnny Long Road
# 5304  3001         NaN  1463 Johnny Long Road
# 5305  3001         NaN  1463 Johnny Long Road
# 5306  3001         NaN  1463 Johnny Long Road
# 5307  3001         NaN  1463 Johnny Long Road
#
#                                amenities/exterior amenities/fireplace  \
# 0                Deck, RV-Park, Sprinkler System,                   2
# 1                                        RV-Park,                   1
# 2                                   Deck, Garden,                   1
# 3     RV-Park, Deck, Sprinkler System, Tool Sheed                 NaN
# ...
