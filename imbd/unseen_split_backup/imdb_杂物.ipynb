# %%
import pandas as pd

# %%
IMDB_con=pd.read_excel('./movie_constraint.xlsx','IMDB')
movie_con=pd.read_excel('./movie_constraint.xlsx','Sheet2')

# %%
IMDB_con
# Out:
#                table             column     type primary key foreign key  \
# 0         title.akas            titleid   string         yes          no
# 1         title.akas           ordering  integer          no          no
# 2         title.akas              title   string          no          no
# 3         title.akas             region   string          no          no
# 4         title.akas           language   string          no          no
# 5         title.akas              types    array          no          no
# 6         title.akas         attributes    array          no          no
# 7         title.akas    isoriginaltitle  boolean          no          no
# 8       title.basics             tconst   string         yes         yes
# 9       title.basics          titletype   string          no          no
# 10      title.basics       primarytitle   string          no          no
# 11      title.basics      originaltitle   string          no          no
# ...

# %%
movie_con
# Out:
#       table            column       type primary key foreign key  size
# 0     actor          actor_id    integer         yes          no   300
# 1     actor        first_name     string          no          no    15
# 2     actor         last_name     string          no          no    15
# 3     actor       last_update  timestamp          no          no    13
# 4   address        address_id    integer         yes          no   650
# ..      ...               ...        ...         ...         ...   ...
# 85    staff       last_update  timestamp          no          no    13
# 86    store          store_id    integer         yes          no     2
# 87    store  manager_staff_id    integer          no         yes     2
# 88    store        address_id    integer          no         yes     2
# 89    store       last_update  timestamp          no          no    13
#
# [90 rows x 6 columns]

# %%
total=len(match['label'])

# %%
(len(movie_con[movie_con['primary key']=='yes'])+len(IMDB_con[IMDB_con['primary key']=='yes']))/129
# Out:
# 0.16279069767441862

# %%
(len(movie_con[movie_con['foreign key']=='yes'])+len(IMDB_con[IMDB_con['foreign key']=='yes']))/129
# Out:
# 0.20930232558139536

# %%
(len(movie_con[movie_con['type']=='string'])+len(IMDB_con[IMDB_con['type']=='string']))/129
# Out:
# 0.3333333333333333

# %%
(len(movie_con[movie_con['type']=='timestamp'])+len(IMDB_con[IMDB_con['type']=='timestamp'])+len(movie_con[movie_con['type']=='YYYY'])+len(IMDB_con[IMDB_con['type']=='YYYY']))/129
# Out:
# 0.18604651162790697

# %%
(len(movie_con[movie_con['type']=='integer'])+len(IMDB_con[IMDB_con['type']=='integer']))/129
# Out:
# 0.32558139534883723

# %%
(len(movie_con[movie_con['type']=='float'])+len(IMDB_con[IMDB_con['type']=='float']))/129
# Out:
# 0.05426356589147287

# %%
(len(movie_con[movie_con['type']=='boolean'])+len(IMDB_con[IMDB_con['type']=='boolean']))/129
# Out:
# 0.031007751937984496

# %%
(len(movie_con[movie_con['type']=='array'])+len(IMDB_con[IMDB_con['type']=='array']))/129
# Out:
# 0.06201550387596899

# %%
match=pd.read_excel('imdb.xlsx')

# %%
# Out:
# 2350

# %%
imdb=pd.read_excel('imdb.xlsx')

# %%
imdb
# Out:
#                              imdb                       saki  \
# 0             title_akas-language       language-language_id
# 1                title_crew-tcons          inventory-film_id
# 2             title_basics-tconst               film-film_id
# 3             title_basics-tconst         film_actor-film_id
# 4             title_basics-genres      film_text-description
# ...                           ...                        ...
# 2345   title_episode-seasonnumber     film_actor-last_update
# 2346       title_basics-startyear           actor-first_name
# 2347            title_akas-region      film-special_features
# 2348  title_ratings-averagerating  film-original_language_id
# 2349            title_akas-region       language-language_id
#
#                                                    des1  \
# 0     contains the following common information for ...
# 1      contains the director and writer information ...
# 2     contains the following basic information for t...
# ...

# %%
imdb=pd.read_excel('imdb.xlsx')
des1_mean=(imdb['des1'].str.len().mean()+imdb['des2'].str.len().mean())/2
des1_min=min(imdb['des1'].str.len().min(),imdb['des2'].str.len().min())
des1_max=max(imdb['des1'].str.len().max(),imdb['des2'].str.len().max())

# %%
des1_mean
# Out:
# 132.31702127659577

# %%
des1_min
# Out:
# 63

# %%
des1_max
# Out:
# 306
