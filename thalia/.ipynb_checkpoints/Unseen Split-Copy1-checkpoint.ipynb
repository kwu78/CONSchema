# %%
import pandas as pd

# %%
match=pd.read_excel("./match.xlsx").drop(columns=['Unnamed: 0'])

# %%
sum(match['label'])
# Out:
# 52

# %%
match.set_index(keys=["source"],inplace=True)

# %%
match.sort_index(inplace=True)
nOmop=match['target'].nunique()
nOmop
# Out:
# 90

# %%
match
# Out:
#                                              target  size1  size2   type1  \
# source
# bu./course/college            arizona./Course/@Code      3      3  string
# bu./course/college              arizona./Course/Day      3      4  string
# bu./course/college       arizona./Course/Instructor      3     15  string
# bu./course/college            arizona./Course/Place      3     12  string
# bu./course/college             arizona./Course/Time      3      8  string
# ...                                             ...    ...    ...     ...
# yale./Course/Instructor          gatech./Course/CRN     30      5  string
# yale./Course/Instructor         gatech./Course/Code     30      4  string
# yale./Course/Instructor     gatech./Course/Building     30     15  string
# yale./Course/Instructor          gatech./Course/Max     30     45  string
# yale./Course/Instructor    gatech./Course/Code/#agg     30      4  string
#
#                            type2  label
# source
# bu./course/college        string      0
# bu./course/college          date      0
# bu./course/college        string      0
# bu./course/college        string      0
# bu./course/college          time      0
# ...                          ...    ...
# yale./Course/Instructor   string      0
# yale./Course/Instructor   string      0
# yale./Course/Instructor   string      0
# yale./Course/Instructor  integer      0
# yale./Course/Instructor   string      0
#
# [1002 rows x 6 columns]

# %%
label=match.iloc[0:,5]
input1=label.groupby(label.index).sum()

input2=input1.head(10)
print (input1)
# Out:
# source
# bu./course/college                     0
# bu./course/courseInfo/@code            0
# bu./course/courseInfo/instructor       1
# bu./course/courseInfo/schedule/days    1
# bu./course/courseInfo/schedule/room    1
#                                       ..
# washu./Course/Title                    2
# yale./Course/@No                       0
# yale./Course/CourseName                1
# yale./Course/DayTime                   0
# yale./Course/Instructor                1
# Name: label, Length: 123, dtype: int64

# %%
freq={}
for k,v in input1.iteritems():
    if v in freq:
        freq[v].append(k)
    else:
        freq[v]=[k]

freq
# Out:
# {0: ['bu./course/college',
#   'bu./course/courseInfo/@code',
#   'bu./course/courseInfo/title',
#   'cmu./Course/Code',
#   'cmu./Course/CourseTitle',
#   'cmu./Course/CourseX-Listed',
#   'cmu./Course/Day',
#   'cmu./Course/Lecturer',
#   'cmu./Course/Room',
#   'cmu./Course/Sec',
#   'cmu./Course/Time',
#   'cmu./Course/Units',
#   'fsu./Course/Code',
#   'fsu./Course/Detail/Bldg/BldgCode',
#   'fsu./Course/Detail/Bldg/Comments',
#   'fsu./Course/Detail/Bldg/Room',
#   'fsu./Course/Detail/Instructor',
#   'fsu./Course/Detail/Seats',
#   'fsu./Course/Detail/Seats/#agg',
#   'fsu./Course/Detail/SeatsOpen',
#   'fsu./Course/Detail/SeatsOpen/#agg',
#   'fsu./Course/Detail/Title',
#   'fsu./Course/ReferenceNo',
#   'fsu./Course/Section',
#   'fsu./Course/Section/#agg',
#   'gatech./Course/Building',
#   'gatech./Course/CRN',
#   'gatech./Course/CRN/#agg',
#   'gatech./Course/Code',
#   'gatech./Course/Code/#agg',
#   'gatech./Course/Department',
#   'gatech./Course/Description',
#   'gatech./Course/Hours',
#   'gatech./Course/Hours/#agg',
#   'gatech./Course/In',
#   'gatech./Course/In/#agg',
#   'gatech./Course/Max',
#   'gatech./Course/Max/#agg',
#   'gatech./Course/Mode',
#   'gatech./Course/Section',
#   'gatech./Course/Title',
#   'hku./Course/CourseSite',
#   'hku./Course/Instructor/Homepage',
#   'hku./Course/Term',
#   'iowa./Course/Details/Coreq',
#   'metu./Course/@Code',
#   'metu./Course/CreditInformation',
#   'metu./Course/DetailedInformation',
#   'metu./Course/Prerequiste',
#   'nyu./Course/CallNo',
#   'toronto./course/#id',
#   'toronto./course/@No',
#   'toronto./course/@level',
#   'toronto./course/@offeredTerm',
#   'toronto./course/instructor/@Email',
#   'toronto./course/instructor/@Name',
#   'toronto./course/location',
#   'toronto./course/text',
#   'ucla./Course/#id',
#   'ucla./Course/CourseInfo/@CourseID',
#   'ucla./Course/CourseInfo/Section',
#   'ucla./Course/CourseInfo/Type',
#   'uiuc./BannerNumber/TimeTable',
#   'umd./Course/#id',
#   'umd./Course/Credits',
#   'umd./Course/GradeMethod',
#   'umd./Course/Section/Time',
#   'umd./Course/Section/Title',
#   'umich./course/@catalognumber',
#   'umich./course/@subject',
#   'umich./course/credits',
#   'umich./course/field',
#   'washu./Course/Instructor',
#   'washu./Course/Time',
#   'yale./Course/@No',
#   'yale./Course/DayTime'],
#  1: ['bu./course/courseInfo/instructor',
#   'bu./course/courseInfo/schedule/days',
#   'bu./course/courseInfo/schedule/room',
#   'bu./course/courseInfo/schedule/time',
#   'fsu./Course/Detail/Bldg/Days',
#   'fsu./Course/Detail/Bldg/TimeBegin',
#   'fsu./Course/Detail/Bldg/TimeEnd',
#   'gatech./Course/Days',
#   'gatech./Course/Instructor',
#   'gatech./Course/Room',
#   'gatech./Course/Time',
#   'hku./Course/CourseNo',
#   'hku./Course/Instructor/Name',
#   'hku./Course/Title',
#   'iowa./Course/CourseNo',
#   'iowa./Course/Details/Description',
#   'iowa./Course/Details/Prereq',
#   'iowa./Course/Title',
#   'metu./Course/HomePage',
#   'metu./Course/Name',
#   'nyu./Course/No',
#   'nyu./Course/Room',
#   'toronto./course/coursewebsite',
#   'toronto./course/prereq',
#   'toronto./course/title',
#   'ucla./Course/CourseInfo/Bldg',
#   'ucla./Course/CourseInfo/Days',
#   'ucla./Course/CourseInfo/Room',
#   'ucla./Course/CourseInfo/TimeBegin',
#   'ucla./Course/CourseInfo/TimeEnd',
#   'ucla./Course/Title',
#   'uiuc./BannerNumber/CourseTitle',
#   'uiuc./BannerNumber/InternetCourse',
#   'uiuc./BannerNumber/UIDirectNumber',
#   'umd./Course/Code',
#   'umd./Course/CourseName',
#   'umich./course/description',
#   'umich./course/name',
#   'umich./course/prerequisite',
#   'washu./Course/Number',
#   'yale./Course/CourseName',
#   'yale./Course/Instructor'],
#  2: ['nyu./Course/Days',
#   'nyu./Course/Instructor',
#   'nyu./Course/Name',
#   'nyu./Course/Time',
#   'washu./Course/Title']}

# %%
matches=pd.read_excel("./match.xlsx")
totalones=len(matches[matches['label']==1])
totalCols=len(input1)
print (totalones)
print (totalCols)
# Out:
# 52
# 123

# %%
import numpy as np

np.random.choice(freq[1])
# Out:
# 'washu./Course/Number'

# %%
nVal=int(totalones*0.1)
nValCols=int(0.1*totalCols)
val=[]
while nVal>0 and len(val)<nValCols:
    newChoice=np.random.choice(nVal+1,1)[0]
    if int(newChoice) in freq:
        if len(freq[newChoice])>0:
            print ("newChoiceselected")
            print (newChoice)
            decision=np.random.choice(freq[newChoice])
            val.append(decision)
            freq[newChoice].remove(decision)
            nVal=nVal-newChoice
while len(val)<nValCols:
    decision=np.random.choice(freq[0])
    val.append(decision)
    freq[0].remove(decision)
print (val)
# Out:
# newChoiceselected
# 0
# newChoiceselected
# 2
# newChoiceselected
# 1
# newChoiceselected
# 2
# ['cmu./Course/Code', 'nyu./Course/Days', 'umich./course/prerequisite', 'nyu./Course/Time', 'metu./Course/@Code', 'gatech./Course/Hours', 'gatech./Course/Title', 'fsu./Course/Detail/SeatsOpen/#agg', 'fsu./Course/Detail/Bldg/Room', 'gatech./Course/Section', 'gatech./Course/In', 'gatech./Course/Max/#agg']

# %%
nTest=int(totalones*0.1)
nTestCols=int(0.1*totalCols)
test=[]
while nTest>0 and len(test)<nTestCols:
    newChoice=np.random.choice(nTest+1,1)[0]
    if int(newChoice) in freq:
        if len(freq[newChoice])>0:
            print ("newChoiceselected")
            print (newChoice)
            decision=np.random.choice(freq[newChoice])
            test.append(decision)
            freq[newChoice].remove(decision)
            nTest=nTest-newChoice
while len(test)<nTestCols:
    decision=np.random.choice(freq[0])
    test.append(decision)
    freq[0].remove(decision)
print (test)
# Out:
# newChoiceselected
# 0
# newChoiceselected
# 0
# newChoiceselected
# 2
# newChoiceselected
# 2
# newChoiceselected
# 0
# newChoiceselected
# 1
# ['umd./Course/#id', 'uiuc./BannerNumber/TimeTable', 'nyu./Course/Name', 'washu./Course/Title', 'cmu./Course/Room', 'umich./course/description', 'nyu./Course/CallNo', 'washu./Course/Time', 'fsu./Course/ReferenceNo', 'gatech./Course/Building', 'cmu./Course/Lecturer', 'metu./Course/DetailedInformation']

# %%
train=[]
for i in freq:
    if len(freq[i])>0:
        for item in freq[i]:
            train.append(item)
train
# Out:
# ['bu./course/college',
#  'bu./course/courseInfo/@code',
#  'bu./course/courseInfo/title',
#  'cmu./Course/CourseTitle',
#  'cmu./Course/CourseX-Listed',
#  'cmu./Course/Day',
#  'cmu./Course/Sec',
#  'cmu./Course/Time',
#  'cmu./Course/Units',
#  'fsu./Course/Code',
#  'fsu./Course/Detail/Bldg/BldgCode',
#  'fsu./Course/Detail/Bldg/Comments',
#  'fsu./Course/Detail/Instructor',
#  'fsu./Course/Detail/Seats',
#  'fsu./Course/Detail/Seats/#agg',
#  'fsu./Course/Detail/SeatsOpen',
#  'fsu./Course/Detail/Title',
#  'fsu./Course/Section',
#  'fsu./Course/Section/#agg',
#  'gatech./Course/CRN',
#  'gatech./Course/CRN/#agg',
#  'gatech./Course/Code',
#  'gatech./Course/Code/#agg',
#  'gatech./Course/Department',
#  'gatech./Course/Description',
#  'gatech./Course/Hours/#agg',
#  'gatech./Course/In/#agg',
#  'gatech./Course/Max',
#  'gatech./Course/Mode',
#  'hku./Course/CourseSite',
#  'hku./Course/Instructor/Homepage',
#  'hku./Course/Term',
#  'iowa./Course/Details/Coreq',
#  'metu./Course/CreditInformation',
#  'metu./Course/Prerequiste',
#  'toronto./course/#id',
#  'toronto./course/@No',
#  'toronto./course/@level',
#  'toronto./course/@offeredTerm',
#  'toronto./course/instructor/@Email',
#  'toronto./course/instructor/@Name',
#  'toronto./course/location',
#  'toronto./course/text',
#  'ucla./Course/#id',
#  'ucla./Course/CourseInfo/@CourseID',
#  'ucla./Course/CourseInfo/Section',
#  'ucla./Course/CourseInfo/Type',
#  'umd./Course/Credits',
#  'umd./Course/GradeMethod',
#  'umd./Course/Section/Time',
#  'umd./Course/Section/Title',
#  'umich./course/@catalognumber',
#  'umich./course/@subject',
#  'umich./course/credits',
#  'umich./course/field',
#  'washu./Course/Instructor',
#  'yale./Course/@No',
#  'yale./Course/DayTime',
#  'bu./course/courseInfo/instructor',
#  'bu./course/courseInfo/schedule/days',
#  'bu./course/courseInfo/schedule/room',
#  'bu./course/courseInfo/schedule/time',
#  'fsu./Course/Detail/Bldg/Days',
#  'fsu./Course/Detail/Bldg/TimeBegin',
#  'fsu./Course/Detail/Bldg/TimeEnd',
#  'gatech./Course/Days',
#  'gatech./Course/Instructor',
#  'gatech./Course/Room',
#  'gatech./Course/Time',
#  'hku./Course/CourseNo',
#  'hku./Course/Instructor/Name',
#  'hku./Course/Title',
#  'iowa./Course/CourseNo',
#  'iowa./Course/Details/Description',
#  'iowa./Course/Details/Prereq',
#  'iowa./Course/Title',
#  'metu./Course/HomePage',
#  'metu./Course/Name',
#  'nyu./Course/No',
#  'nyu./Course/Room',
#  'toronto./course/coursewebsite',
#  'toronto./course/prereq',
#  'toronto./course/title',
#  'ucla./Course/CourseInfo/Bldg',
#  'ucla./Course/CourseInfo/Days',
#  'ucla./Course/CourseInfo/Room',
#  'ucla./Course/CourseInfo/TimeBegin',
#  'ucla./Course/CourseInfo/TimeEnd',
#  'ucla./Course/Title',
#  'uiuc./BannerNumber/CourseTitle',
#  'uiuc./BannerNumber/InternetCourse',
#  'uiuc./BannerNumber/UIDirectNumber',
#  'umd./Course/Code',
#  'umd./Course/CourseName',
#  'umich./course/name',
#  'washu./Course/Number',
#  'yale./Course/CourseName',
#  'yale./Course/Instructor',
#  'nyu./Course/Instructor']

# %%
import xlsxwriter
training=pd.DataFrame()
writer1 = pd.ExcelWriter('./train_thalia.xlsx', engine='xlsxwriter')
for m in train:
    training=training.append(matches.loc[matches['source']==m])
training.to_excel(writer1,sheet_name='thalia_train',index=False)
print (len(training))
writer1.save()
training
# Out:
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/4241276119.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   training=training.append(matches.loc[matches['source']==m])
# 755
#      Unnamed: 0                  source                       target  size1  \
# 0             0      bu./course/college        arizona./Course/@Code      3
# 1             1      bu./course/college          arizona./Course/Day      3
# 2             2      bu./course/college   arizona./Course/Instructor      3
# 3             3      bu./course/college        arizona./Course/Place      3
# 4             4      bu./course/college         arizona./Course/Time      3
# ..          ...                     ...                          ...    ...
# 775         775  nyu./Course/Instructor     ksu./Course/Details/Room     15
# 776         776  nyu./Course/Instructor  ksu./Course/Details/Section     15
# 777         777  nyu./Course/Instructor     ksu./Course/Details/Time     15
# 778         778  nyu./Course/Instructor     ksu./Course/Details/Type     15
# 779         779  nyu./Course/Instructor            ksu./Course/Title     15
#
#      size2   type1   type2  label
# 0        3  string  string      0
# 1        4  string    date      0
# 2       15  string  string      0
# 3       12  string  string      0
# 4        8  string    time      0
# ..     ...     ...     ...    ...
# 775      7  string  string      0
# 776      3  string  string      0
# 777      8  string    time      0
# 778      3  string  string      0
# 779     20  string  string      0
#
# [755 rows x 8 columns]

# %%
validating=pd.DataFrame()
writer2=pd.ExcelWriter('./val_thalia.xlsx',engine='xlsxwriter')
for m in val:
    validating=validating.append(matches.loc[matches['source']==m])
print (len(validating))
validating.to_excel(writer2,sheet_name='thalia_val',index=False)
writer2.save()
print (val)
# Out:
# 116
# ['cmu./Course/Code', 'nyu./Course/Days', 'umich./course/prerequisite', 'nyu./Course/Time', 'metu./Course/@Code', 'gatech./Course/Hours', 'gatech./Course/Title', 'fsu./Course/Detail/SeatsOpen/#agg', 'fsu./Course/Detail/Bldg/Room', 'gatech./Course/Section', 'gatech./Course/In', 'gatech./Course/Max/#agg']
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/3488469987.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   validating=validating.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/3488469987.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   validating=validating.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/3488469987.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   validating=validating.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/3488469987.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   validating=validating.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/3488469987.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   validating=validating.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/3488469987.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   validating=validating.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/3488469987.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   validating=validating.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/3488469987.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   validating=validating.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/3488469987.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   validating=validating.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/3488469987.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   validating=validating.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/3488469987.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   validating=validating.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/3488469987.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   validating=validating.append(matches.loc[matches['source']==m])

# %%
testing=pd.DataFrame()
writer3=pd.ExcelWriter('./test_thalia.xlsx',engine='xlsxwriter')
for m in test:
    testing=testing.append(matches.loc[matches['source']==m])
print (len(testing))
testing.to_excel(writer3,sheet_name='thalia_test',index=False)
writer3.save()
print (test)
# Out:
# 131
# ['umd./Course/#id', 'uiuc./BannerNumber/TimeTable', 'nyu./Course/Name', 'washu./Course/Title', 'cmu./Course/Room', 'umich./course/description', 'nyu./Course/CallNo', 'washu./Course/Time', 'fsu./Course/ReferenceNo', 'gatech./Course/Building', 'cmu./Course/Lecturer', 'metu./Course/DetailedInformation']
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/940700992.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   testing=testing.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/940700992.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   testing=testing.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/940700992.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   testing=testing.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/940700992.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   testing=testing.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/940700992.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   testing=testing.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/940700992.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   testing=testing.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/940700992.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   testing=testing.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/940700992.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   testing=testing.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/940700992.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   testing=testing.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/940700992.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   testing=testing.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/940700992.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   testing=testing.append(matches.loc[matches['source']==m])
# /var/folders/hd/krkf0bwn52s0tf7r0fqk2c1c0000gp/T/ipykernel_20713/940700992.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   testing=testing.append(matches.loc[matches['source']==m])

# %%
testing
# Out:
#      Unnamed: 0                            source  \
# 863         863                   umd./Course/#id
# 864         864                   umd./Course/#id
# 865         865                   umd./Course/#id
# 866         866                   umd./Course/#id
# 867         867                   umd./Course/#id
# ..          ...                               ...
# 324         324  metu./Course/DetailedInformation
# 325         325  metu./Course/DetailedInformation
# 326         326  metu./Course/DetailedInformation
# 327         327  metu./Course/DetailedInformation
# 328         328  metu./Course/DetailedInformation
#
#                               target  size1  size2    type1    type2  label
# 863      stanford./Course/CourseCode     52      5  integer   string      0
# 864      stanford./Course/CourseName     52     60  integer   string      0
# 865         stanford./Course/DayTime     52      8  integer     time      0
# 866      stanford./Course/Instructor     52     15  integer   string      0
# 867            stanford./Course/Room     52      8  integer   string      0
# ..                               ...    ...    ...      ...      ...    ...
# 324           hku./Course/CourseSite     70     25   string   string      0
# 325  hku./Course/Instructor/Homepage     70     40   string   string      0
# 326      hku./Course/Instructor/Name     70     15   string   string      0
# 327                 hku./Course/Term     70      2   string  integer      0
# 328                hku./Course/Title     70     60   string   string      0
#
# [131 rows x 8 columns]

# %%
validating
# Out:
#      Unnamed: 0                   source                               target  \
# 665         665         cmu./Course/Code                   bu./course/college
# 666         666         cmu./Course/Code          bu./course/courseInfo/@code
# 667         667         cmu./Course/Code     bu./course/courseInfo/instructor
# 668         668         cmu./Course/Code  bu./course/courseInfo/schedule/days
# 669         669         cmu./Course/Code  bu./course/courseInfo/schedule/room
# ..          ...                      ...                                  ...
# 105         105  gatech./Course/Max/#agg                arizona./Course/@Code
# 106         106  gatech./Course/Max/#agg                  arizona./Course/Day
# 107         107  gatech./Course/Max/#agg           arizona./Course/Instructor
# 108         108  gatech./Course/Max/#agg                arizona./Course/Place
# 109         109  gatech./Course/Max/#agg                 arizona./Course/Time
#
#      size1  size2    type1   type2  label
# 665      6      3   string  string      0
# 666      6      7   string  string      0
# 667      6     10   string  string      0
# 668      6      4   string    date      0
# 669      6      6   string  string      0
# ..     ...    ...      ...     ...    ...
# 105     45      3  integer  string      0
# 106     45      4  integer    date      0
# 107     45     15  integer  string      0
# 108     45     12  integer  string      0
# 109     45      8  integer    time      0
#
# [116 rows x 8 columns]

# %%
training
# Out:
#      Unnamed: 0                  source                       target  size1  \
# 0             0      bu./course/college        arizona./Course/@Code      3
# 1             1      bu./course/college          arizona./Course/Day      3
# 2             2      bu./course/college   arizona./Course/Instructor      3
# 3             3      bu./course/college        arizona./Course/Place      3
# 4             4      bu./course/college         arizona./Course/Time      3
# ..          ...                     ...                          ...    ...
# 775         775  nyu./Course/Instructor     ksu./Course/Details/Room     15
# 776         776  nyu./Course/Instructor  ksu./Course/Details/Section     15
# 777         777  nyu./Course/Instructor     ksu./Course/Details/Time     15
# 778         778  nyu./Course/Instructor     ksu./Course/Details/Type     15
# 779         779  nyu./Course/Instructor            ksu./Course/Title     15
#
#      size2   type1   type2  label
# 0        3  string  string      0
# 1        4  string    date      0
# 2       15  string  string      0
# 3       12  string  string      0
# 4        8  string    time      0
# ..     ...     ...     ...    ...
# 775      7  string  string      0
# 776      3  string  string      0
# 777      8  string    time      0
# 778      3  string  string      0
# 779     20  string  string      0
#
# [755 rows x 8 columns]
